# %%
from src.Restorer.Cond_NAF_SSID import NAFNet

# %%
NAFNet(
    img_channel=3,
    width=16,
    middle_blk_num=12,
    enc_blk_nums=[2, 2, 2, 2],
    dec_blk_nums=[2, 2, 2, 2,],
    use_add=False,
    global_channel=16
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 NAFNet(
#       2     img_channel=3,
#       3     width=16,
#       4     middle_blk_num=12,
#       5     enc_blk_nums=[2, 2, 2, 2],
#       6     dec_blk_nums=[2, 2, 2, 2,],
#       7     use_add=False,
#       8     global_channel=16
#       9 )
#
# File ~/Develop/Restorer/src/Restorer/Cond_NAF_SSID.py:180, in NAFNet.__init__(self, img_channel, width, middle_blk_num, enc_blk_nums, dec_blk_nums, use_add, global_channel)
#     176 super().__init__()
#     177 self.global_channel = global_channel
#     178 self.global_channel_producer = nn.Sequential(
#     179     nn.AdaptiveAvgPool2d(1),
# --> 180     nn.Conv2d(width, global_channel)
#     181 )
#     182 self.intro = nn.Conv2d(in_channels=img_channel, out_channels=width, kernel_size=3, padding=1, stride=1, groups=1,
# ...
